# %%
from embedding_evaluation_framework import EmbeddingData, eval_n2v
import pandas as pd
import numpy as np
import os

# %%
lrs = [0.005,0.025,0.125]
negs = [5,10,15,20]

# %%
inits = 20
splits = 100

# %%
val_out = 'eval/line-1.csv'

# %%
if os.path.exists(val_out):
    df_n2v = pd.read_csv(val_out)
else:
    df_n2v = pd.DataFrame(columns='splits inits lr neg val_acc val_avg val_std'.split())
# df_n2v

# %%
def contains(df_val,lr,neg):
    return ((df_val['lr']==lr) & (df_val['neg']==neg)).any()

# %%
for lr in lrs:
    for neg in negs:
        if contains(df_n2v,lr,neg):
            print('already calculated!')
            continue
        print(f'evaluating lr={lr},neg={neg}')
        vals = []
        tests = []
        for init in range(inits):
            print(f' init {init}')
            emb = EmbeddingData(f'/tmp/lineUndlr{lr}neg{neg}EmbCoraInit{init}','cora',f'line_{neg}_{lr}',directed=False,initialization=f'line1/{init}')
            val = eval_n2v(emb[0],num_splits=splits)
            vals = vals + val
#             tests = tests + test
        df_n2v = df_n2v.append({'splits':splits, 'inits':inits, 'lr':lr, 'neg':neg,
                                'val_acc':vals, 'val_avg':np.mean(vals), 'val_std':np.std(vals),
#                                 'test_acc':tests, 'test_avg':np.mean(tests), 'test_std':np.std(tests)
                               },ignore_index=True)
        df_n2v.to_csv(val_out,index=False)
# Out:
# evaluating lr=0.005,neg=5
#  init 0
#  init 1
#  init 2
# Processing...
# 0
# 0
# Done!
#  init 3
# Processing...
# 0
# 0
# Done!
#  init 4
# Processing...
# 0
# 0
# Done!
#  init 5
# Processing...
# 0
# 0
# Done!
#  init 6
# Processing...
# 0
# 0
# Done!
#  init 7
# Processing...
# 0
# 0
# Done!
#  init 8
# Processing...
# 0
# 0
# Done!
#  init 9
# Processing...
# 0
# 0
# Done!
#  init 10
# Processing...
# 0
# 0
# Done!
#  init 11
# Processing...
# 0
# 0
# Done!
#  init 12
# Processing...
# 0
# 0
# Done!
#  init 13
# Processing...
# 0
# 0
# Done!
#  init 14
# Processing...
# 0
# 0
# Done!
#  init 15
# Processing...
# 0
# 0
# Done!
#  init 16
# Processing...
# 0
# 0
# Done!
#  init 17
# Processing...
# 0
# 0
# Done!
#  init 18
# Processing...
# 0
# 0
# Done!
#  init 19
# Processing...
# 0
# 0
# Done!
# evaluating lr=0.005,neg=10
#  init 0
#  init 1
#  init 2
# Processing...
# 0
# 0
# Done!
#  init 3
# Processing...
# 0
# 0
# Done!
#  init 4
# Processing...
# 0
# 0
# Done!
#  init 5
# Processing...
# 0
# 0
# Done!
#  init 6
# Processing...
# 0
# 0
# Done!
#  init 7
# Processing...
# 0
# 0
# Done!
#  init 8
# Processing...
# 0
# 0
# Done!
#  init 9
# Processing...
# 0
# 0
# Done!
#  init 10
# Processing...
# 0
# 0
# Done!
#  init 11
# Processing...
# 0
# 0
# Done!
#  init 12
# Processing...
# 0
# 0
# Done!
#  init 13
# Processing...
# 0
# 0
# Done!
#  init 14
# Processing...
# 0
# 0
# Done!
#  init 15
# Processing...
# 0
# 0
# Done!
#  init 16
# Processing...
# 0
# 0
# Done!
#  init 17
# Processing...
# 0
# 0
# Done!
#  init 18
# Processing...
# 0
# 0
# Done!
#  init 19
# Processing...
# 0
# 0
# Done!
# evaluating lr=0.005,neg=15
#  init 0
# Processing...
# 0
# 0
# Done!
#  init 1
# Processing...
# 0
# 0
# Done!
#  init 2
# Processing...
# 0
# 0
# Done!
#  init 3
# Processing...
# 0
# 0
# Done!
#  init 4
# Processing...
# 0
# 0
# Done!
#  init 5
# Processing...
# 0
# 0
# Done!
#  init 6
# Processing...
# 0
# 0
# Done!
#  init 7
# Processing...
# 0
# 0
# Done!
#  init 8
# Processing...
# 0
# 0
# Done!
#  init 9
# Processing...
# 0
# 0
# Done!
#  init 10
# Processing...
# 0
# 0
# Done!
#  init 11
# Processing...
# 0
# 0
# Done!
#  init 12
# Processing...
# 0
# 0
# Done!
#  init 13
# Processing...
# 0
# 0
# Done!
#  init 14
# Processing...
# 0
# 0
# Done!
#  init 15
# Processing...
# 0
# 0
# Done!
#  init 16
# Processing...
# 0
# 0
# Done!
#  init 17
# Processing...
# 0
# 0
# Done!
#  init 18
# Processing...
# 0
# 0
# Done!
#  init 19
# Processing...
# 0
# 0
# Done!
# evaluating lr=0.005,neg=20
#  init 0
# Processing...
# 0
# 0
# Done!
#  init 1
# Processing...
# 0
# 0
# Done!
#  init 2
# Processing...
# 0
# 0
# Done!
#  init 3
# Processing...
# 0
# 0
# Done!
#  init 4
# Processing...
# 0
# 0
# Done!
#  init 5
# Processing...
# 0
# 0
# Done!
#  init 6
# Processing...
# 0
# 0
# Done!
#  init 7
# Processing...
# 0
# 0
# Done!
#  init 8
# Processing...
# 0
# 0
# Done!
#  init 9
# Processing...
# 0
# 0
# Done!
#  init 10
# Processing...
# 0
# 0
# Done!
#  init 11
# Processing...
# 0
# 0
# Done!
#  init 12
# Processing...
# 0
# 0
# Done!
#  init 13
# Processing...
# 0
# 0
# Done!
#  init 14
# Processing...
# 0
# 0
# Done!
#  init 15
# Processing...
# 0
# 0
# Done!
#  init 16
# Processing...
# 0
# 0
# Done!
#  init 17
# Processing...
# 0
# 0
# Done!
#  init 18
# Processing...
# 0
# 0
# Done!
#  init 19
# Processing...
# 0
# 0
# Done!
# evaluating lr=0.025,neg=5
#  init 0
# Processing...
# 0
# 0
# Done!
#  init 1
# Processing...
# 0
# 0
# Done!
#  init 2
# Processing...
# 0
# 0
# Done!
#  init 3
# Processing...
# 0
# 0
# Done!
#  init 4
# Processing...
# 0
# 0
# Done!
#  init 5
# Processing...
# 0
# 0
# Done!
#  init 6
# Processing...
# 0
# 0
# Done!
#  init 7
# Processing...
# 0
# 0
# Done!
#  init 8
# Processing...
# 0
# 0
# Done!
#  init 9
# Processing...
# 0
# 0
# Done!
#  init 10
# Processing...
# 0
# 0
# Done!
#  init 11
# Processing...
# 0
# 0
# Done!
#  init 12
# Processing...
# 0
# 0
# Done!
#  init 13
# Processing...
# 0
# 0
# Done!
#  init 14
# Processing...
# 0
# 0
# Done!
#  init 15
# Processing...
# 0
# 0
# Done!
#  init 16
# Processing...
# 0
# 0
# Done!
#  init 17
# Processing...
# 0
# 0
# Done!
#  init 18
# Processing...
# 0
# 0
# Done!

# %%
df_n2v

# %%
val_out = 'eval/line-2.csv'

# %%
if os.path.exists(val_out):
    df_line2 = pd.read_csv(val_out)
else:
    df_line2 = pd.DataFrame(columns='splits inits lr neg val_acc val_avg val_std'.split())

# %%
for lr in lrs:
    for neg in negs:
        if contains(df_line2,lr,neg):
            print('already calculated!')
            continue
        print(f'evaluating lr={lr},neg={neg}')
        vals = []
        tests = []
        for init in range(inits):
            print(f' init {init}')
            emb = EmbeddingData(f'/tmp/line2Undlr{lr}neg{neg}EmbCoraInit{init}','cora',f'line_{neg}_{lr}',directed=False,initialization=f'line2/{init}')
            val = eval_n2v(emb[0],num_splits=splits)
            vals = vals + val
#             tests = tests + test
        df_line2 = df_line2.append({'splits':splits, 'inits':inits, 'lr':lr, 'neg':neg,
                                'val_acc':vals, 'val_avg':np.mean(vals), 'val_std':np.std(vals),
#                                 'test_acc':tests, 'test_avg':np.mean(tests), 'test_std':np.std(tests)
                               },ignore_index=True)
        df_line2.to_csv(val_out,index=False)
