# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys
sys.path.insert(0,'..')
from src.misc.separator import splitDataFrameList
from scipy.stats import ttest_rel,ttest_ind

# %%
def load_model_results(models,datasets):
    dfs = []
    for model in models:
        for dataset in datasets:
            df = pd.read_csv(f'../reports/results/test_acc/{model}_{dataset}.csv')
            df['dataset'] = dataset
            dfs.append(df[(df.splits == 100) & (df.inits == 20)])
    return pd.concat(dfs,ignore_index=True)

# %%
datasets = 'texas wisconsin cornell washington'.split()
df_results = load_model_results('gcn'.split(),datasets)
view_columns = 'dataset conv arch test_accs'.split()
df_results = df_results[view_columns].rename(columns={'test_accs':'test_acc','arch':'directionality'})
df_results
# Out:
#        dataset     conv directionality  \
# 0        texas  GCNConv              M
# 1        texas  GCNConv              B
# 2        texas  GCNConv              T
# 3    wisconsin  GCNConv              M
# 4    wisconsin  GCNConv              B
# 5    wisconsin  GCNConv              T
# 6      cornell  GCNConv              M
# 7      cornell  GCNConv              B
# 8      cornell  GCNConv              T
# 9   washington  GCNConv              M
# 10  washington  GCNConv              B
# 11  washington  GCNConv              T
#
#                                              test_acc
# 0   [0.5, 0.4067796610169492, 0.5423728813559322, ...
# 1   [0.3813559322033898, 0.4830508474576271, 0.610...
# 2   [0.1694915254237288, 0.5508474576271186, 0.330...
# 3   [0.22624434389140272, 0.4660633484162896, 0.40...
# 4   [0.28054298642533937, 0.13574660633484162, 0.4...
# 5   [0.4434389140271493, 0.24434389140271492, 0.41...
# 6   [0.33980582524271846, 0.47572815533980584, 0.5...
# ...

# %%
for i in range(4):
    A = np.array([float(x) for x in df_results.loc[i*3+0,'test_acc'][1:-1].split(', ')])
    B = np.array([float(x) for x in df_results.loc[i*3+1,'test_acc'][1:-1].split(', ')])
    C = np.array([float(x) for x in df_results.loc[i*3+2,'test_acc'][1:-1].split(', ')])
    print(f'{ttest_rel(A,B)},\n{ttest_rel(A,C)},\n{ttest_rel(B,C)}\n\n')
# Out:
# Ttest_relResult(statistic=-9.096877676325565, pvalue=2.183097059130298e-19),
# Ttest_relResult(statistic=-3.212521301766707, pvalue=0.0013366825530653635),
# Ttest_relResult(statistic=5.307509785062933, pvalue=1.2346354623538722e-07)
#
#
# Ttest_relResult(statistic=12.527143126166383, pvalue=1.0289865152320687e-34),
# Ttest_relResult(statistic=11.347735158635935, pvalue=5.736829613343659e-29),
# Ttest_relResult(statistic=-1.376463663881773, pvalue=0.16883228393731173)
#
#
# Ttest_relResult(statistic=9.429444164650713, pvalue=1.1006541474859606e-20),
# Ttest_relResult(statistic=7.773126132438449, pvalue=1.2158236363649994e-14),
# Ttest_relResult(statistic=-1.7757086143090048, pvalue=0.07593305782499143)
#
#
# Ttest_relResult(statistic=-15.714863155854239, pvalue=1.4648594149890862e-52),
# Ttest_relResult(statistic=-12.254045113970358, pvalue=2.4318526956684403e-33),
# Ttest_relResult(statistic=3.5279313510980863, pvalue=0.0004282749581159658)

# %%
datasets = 'cora citeseer pubmed cora_full'.split()
df_results = load_model_results('gat'.split(),datasets)
view_columns = 'dataset conv arch test_accs'.split()
df_results = df_results[view_columns].rename(columns={'test_accs':'test_acc','arch':'directionality'})
df_results
# Out:
# /home/hhussain/anaconda3/envs/nips2/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#       dataset     conv directionality  \
# 0        cora  GATConv              M
# 1        cora  GATConv              B
# 2        cora  GATConv              T
# 3    citeseer  GATConv              M
# 4    citeseer  GATConv              B
# 5    citeseer  GATConv              T
# 6      pubmed  GATConv              M
# 7      pubmed  GATConv              B
# 8      pubmed  GATConv              T
# 9   cora_full  GATConv              M
# 10  cora_full  GATConv              B
# 11  cora_full  GATConv              T
#
#                                              test_acc
# 0   [0.7756440281030444, 0.7522248243559719, 0.765...
# ...

# %%
for i in range(4):
    A = np.array([float(x) for x in df_results.loc[i*3+0,'test_acc'][1:-1].split(', ')])
    B = np.array([float(x) for x in df_results.loc[i*3+1,'test_acc'][1:-1].split(', ')])
    C = np.array([float(x) for x in df_results.loc[i*3+2,'test_acc'][1:-1].split(', ')])
    print(f'{ttest_rel(A,B)},\n{ttest_rel(A,C)},\n{ttest_rel(B,C)}\n\n')
# Out:
# Ttest_relResult(statistic=-2.174096423236533, pvalue=0.02981486398135758),
# Ttest_relResult(statistic=-5.023278844904001, pvalue=5.531118139002201e-07),
# Ttest_relResult(statistic=-3.948230198973742, pvalue=8.145687158227376e-05)
#
#
# Ttest_relResult(statistic=15.48789737540607, pvalue=3.4855720349929865e-51),
# Ttest_relResult(statistic=8.501143996372084, pvalue=3.615911582820185e-17),
# Ttest_relResult(statistic=-8.01397890169108, pvalue=1.869403151188447e-15)
#
#
# Ttest_relResult(statistic=12.022878474672995, pvalue=3.376775894788045e-32),
# Ttest_relResult(statistic=5.305219334229703, pvalue=1.2500208980711806e-07),
# Ttest_relResult(statistic=-7.061261241629123, pvalue=2.2678322003111093e-12)
#
#
# Ttest_relResult(statistic=-32.58629800227054, pvalue=3.482054721792284e-187),
# Ttest_relResult(statistic=-38.00861189786213, pvalue=2.244515023539559e-238),
# Ttest_relResult(statistic=-4.925457813047544, pvalue=9.107742754313526e-07)
